# %%
import nltk
from nltk.corpus import gutenberg

nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/parkhyerin/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
from nltk.text import Text

# corpus = nltk.word_tokenize(sample_text)
corpus = gutenberg.words('austen-emma.txt')
text = Text(corpus)
text.concordance("anxious")
# Out:
# Displaying 25 of 31 matches:
# good sense than you do , or am more anxious for her present comfort ; for I can
# rs would think and say , and was so anxious that they should not fancy her ungr
# ng ." " Come ," said he , " you are anxious for a compliment , so I will tell y
#  our conduct to fools . If they are anxious to see you _happily_ married , here
# bute of admiration . If he had been anxious for secrecy , he would not have lef
# re . I wish I were anywhere else ." Anxious to separate herself from them as fa
# nsufferable !"-- Yet he would be so anxious for her being perfectly warm , woul
#  be to you ! and Mrs . Weston is so anxious to be acquainted with him , that sh
# es . He professed himself extremely anxious about her fair friend -- her fair ,
# count , than on Harriet ' s -- more anxious that she should escape the infectio
# isit , solicitude for their shoes , anxious inquiries after Mr . Woodhouse ' s
# ...
